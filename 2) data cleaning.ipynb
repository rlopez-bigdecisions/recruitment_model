# %%
import pandas as pd

from sklearn.preprocessing import StandardScaler

# %% [markdown]
# # Load data

# %%
df_train = pd.read_parquet("data/df_train.parquet")
df_train
# Out:
#              id  professionality  visual  grammar  ai_likelihood  education  \
# 0    CVANON0002              4.0     3.0      5.0            3.0        4.0
# 1    CVANON0247              7.0     6.0      8.0            4.0       12.0
# 2    CVANON0009              7.0     6.0      6.0            5.0       15.0
# 3    CVANON0238              7.0     6.0      5.0            4.0       24.0
# 4    CVANON0269              7.0     6.0      8.0            3.0       12.0
# ..          ...              ...     ...      ...            ...        ...
# 284  CVANON0318              5.0     4.0      3.0            6.0        6.0
# 285  CVANON0210              8.0     7.0      6.0            5.0        7.0
# 286  CVANON0206              7.0     6.0      8.0            3.0       13.0
# 287  CVANON0185              7.0     6.0      6.0            5.0       10.0
# 288  CVANON0119              6.0     5.0      8.0            4.0       22.0
#
#      experience  languages  points_9m
# 0      9.833333        8.0   3617.798
# 1      3.083333       10.0   1271.650
# 2      4.166667       11.0   2569.874
# 3     10.500000        0.0    685.200
# 4      8.000000       13.0    652.800
# ..          ...        ...        ...
# 284   13.916667        8.0    164.000
# 285  284.000000       18.0   2292.700
# 286   25.583333       17.0     82.500
# 287   11.666667        3.0    130.500
# 288   74.500000       16.0        NaN
#
# [289 rows x 9 columns]

# %%
df_predict = pd.read_parquet("data/df_predict.parquet")
df_predict
# Out:
#             id  professionality  visual  grammar  ai_likelihood  education  \
# 0   CVANON0002              3.0     4.0      5.0            1.0        5.0
# 1   CVANON0009              3.0     4.0      6.0            2.0       10.0
# 2   CVANON0033              6.0     5.0      8.0            3.0        8.0
# 3   CVANON0010              6.0     5.0      6.0            5.0       10.0
# 4   CVANON0015              3.0     4.0      3.0            6.0        3.0
# ..         ...              ...     ...      ...            ...        ...
# 76  CVANON0018              8.0     6.0      7.0            4.0       25.0
# 77  CVANON0019              6.0     5.0      4.0            3.0       13.0
# 78  CVANON0070              6.0     5.0      5.0            4.0        5.0
# 79  CVANON0017              7.0     5.0      4.0            3.0       11.0
# 80  CVANON0059              7.0     5.0      6.0            4.0        5.0
#
#     experience  languages
# 0     0.000000       10.0
# 1     0.000000       10.0
# 2     5.000000       10.0
# 3     0.333333        6.0
# 4     0.000000        8.0
# ..         ...        ...
# 76   31.416667       13.0
# 77   22.083333        9.0
# 78    5.333333        8.0
# 79   23.583333       12.0
# 80    9.500000        9.0
#
# [81 rows x 8 columns]

# %% [markdown]
# # Check nulls

# %%
df_train.isnull().sum()
# Out:
# id                  0
# professionality     0
# visual              0
# grammar             0
# ai_likelihood       0
# education           0
# experience          0
# languages           0
# points_9m          72
# dtype: int64

# %%
df_train = df_train.dropna(subset=["points_9m"])

# %%
# Check if any column has null values
df_train.isnull().sum()
# Out:
# id                 0
# professionality    0
# visual             0
# grammar            0
# ai_likelihood      0
# education          0
# experience         0
# languages          0
# points_9m          0
# dtype: int64

# %%
df_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 217 entries, 0 to 287
# Data columns (total 9 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   id               217 non-null    object
#  1   professionality  217 non-null    float64
#  2   visual           217 non-null    float64
#  3   grammar          217 non-null    float64
#  4   ai_likelihood    217 non-null    float64
#  5   education        217 non-null    float64
#  6   experience       217 non-null    float64
#  7   languages        217 non-null    float64
#  8   points_9m        217 non-null    float64
# dtypes: float64(8), object(1)
# memory usage: 17.0+ KB

# %%
df_predict.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 81 entries, 0 to 80
# Data columns (total 8 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   id               81 non-null     object
#  1   professionality  81 non-null     float64
#  2   visual           81 non-null     float64
#  3   grammar          81 non-null     float64
#  4   ai_likelihood    81 non-null     float64
#  5   education        81 non-null     float64
#  6   experience       81 non-null     float64
#  7   languages        81 non-null     float64
# dtypes: float64(7), object(1)
# memory usage: 5.2+ KB

# %% [markdown]
# # Scaling

# %%
scaler = StandardScaler()

# %%
df_train.iloc[:, 1:-1] = scaler.fit_transform(df_train.iloc[:, 1:-1])
df_train
# Out:
#              id  professionality    visual   grammar  ai_likelihood  \
# 0    CVANON0002        -2.345824 -2.376936 -0.865650      -0.649081
# 1    CVANON0247         0.371492  0.604539  1.070907       0.220367
# 2    CVANON0009         0.371492  0.604539 -0.220131       1.089815
# 3    CVANON0238         0.371492  0.604539 -0.865650       0.220367
# 4    CVANON0269         0.371492  0.604539  1.070907      -0.649081
# ..          ...              ...       ...       ...            ...
# 283  CVANON0311         0.371492  0.604539  1.070907       0.220367
# 284  CVANON0318        -1.440052 -1.383111 -2.156688       1.959263
# 285  CVANON0210         1.277264  1.598363 -0.220131       1.089815
# 286  CVANON0206         0.371492  0.604539  1.070907      -0.649081
# 287  CVANON0185         0.371492  0.604539 -0.220131       1.089815
#
#      education  experience  languages  points_9m
# 0    -0.811672   -0.451910  -0.263813   3617.798
# 1     0.313777   -0.658899   0.169880   1271.650
# 2     0.735821   -0.625678   0.386726   2569.874
# 3     2.001951   -0.431466  -1.998586    685.200
# 4     0.313777   -0.508129   0.820419    652.800
# ..         ...         ...        ...        ...
# 283   1.720589   -0.416134   0.386726     41.600
# 284  -0.530310   -0.326694  -0.263813    164.000
# 285  -0.389628    7.955434   1.904652   2292.700
# 286   0.454458    0.031065   1.687805     82.500
# 287   0.032415   -0.395690  -1.348046    130.500
#
# [217 rows x 9 columns]

# %%
df_predict.iloc[:, 1:] = scaler.transform(df_predict.iloc[:, 1:])
df_predict
# Out:
#             id  professionality    visual   grammar  ai_likelihood  education  \
# 0   CVANON0002        -3.251596 -1.383111 -0.865650      -2.387977  -0.670991
# 1   CVANON0009        -3.251596 -1.383111 -0.220131      -1.518529   0.032415
# 2   CVANON0033        -0.534280 -0.389286  1.070907      -0.649081  -0.248947
# 3   CVANON0010        -0.534280 -0.389286 -0.220131       1.089815   0.032415
# 4   CVANON0015        -3.251596 -1.383111 -2.156688       1.959263  -0.952353
# ..         ...              ...       ...       ...            ...        ...
# 76  CVANON0018         1.277264  0.604539  0.425388       0.220367   2.142632
# 77  CVANON0019        -0.534280 -0.389286 -1.511169      -0.649081   0.454458
# 78  CVANON0070        -0.534280 -0.389286 -0.865650       0.220367  -0.670991
# 79  CVANON0017         0.371492 -0.389286 -1.511169      -0.649081   0.173096
# 80  CVANON0059         0.371492 -0.389286 -0.220131       0.220367  -0.670991
#
#     experience  languages
# 0    -0.753450   0.169880
# 1    -0.753450   0.169880
# 2    -0.600124   0.169880
# 3    -0.743228  -0.697506
# 4    -0.753450  -0.263813
# ..         ...        ...
# 76    0.209945   0.820419
# 77   -0.076262  -0.046967
# 78   -0.589902  -0.263813
# 79   -0.030265   0.603573
# 80   -0.462131  -0.046967
#
# [81 rows x 8 columns]

# %%
df_train.describe()
# Out:
#        professionality        visual       grammar  ai_likelihood  \
# count     2.170000e+02  2.170000e+02  2.170000e+02   2.170000e+02
# mean     -1.064177e-16 -4.133918e-16 -3.683689e-17  -1.146037e-16
# std       1.002312e+00  1.002312e+00  1.002312e+00   1.002312e+00
# min      -5.063141e+00 -4.364585e+00 -3.447726e+00  -2.387977e+00
# 25%      -5.342803e-01 -3.892862e-01 -8.656498e-01  -6.490810e-01
# 50%       3.714918e-01 -3.892862e-01 -2.201309e-01   2.203670e-01
# 75%       3.714918e-01  6.045386e-01  1.070907e+00   1.089815e+00
# max       2.183036e+00  2.592188e+00  1.716426e+00   2.828711e+00
#
#           education    experience     languages    points_9m
# count  2.170000e+02  2.170000e+02  2.170000e+02   217.000000
# mean   1.227896e-16 -5.730183e-17  1.268826e-16  1068.521634
# std    1.002312e+00  1.002312e+00  1.002312e+00  1099.994636
# min   -1.374396e+00 -7.534496e-01 -1.998586e+00     1.000000
# 25%   -6.709907e-01 -6.103459e-01 -4.806598e-01   161.700000
# 50%   -2.489473e-01 -3.496927e-01  1.698798e-01   670.265000
# 75%    4.544584e-01  3.070512e-01  6.035728e-01  1706.273800
# max    3.690125e+00  7.955434e+00  3.205731e+00  5511.000000

# %%
df_predict.describe()
# Out:
#        professionality     visual    grammar  ai_likelihood  education  \
# count        81.000000  81.000000  81.000000      81.000000  81.000000
# mean         -0.265903  -0.119358  -0.514998       0.005688   0.150518
# std           1.202022   1.006322   0.797480       1.015161   1.333034
# min          -3.251596  -3.370761  -2.156688      -2.387977  -1.374396
# 25%          -0.534280  -0.389286  -0.865650      -0.649081  -0.670991
# 50%           0.371492  -0.389286  -0.865650       0.220367  -0.248947
# 75%           0.371492   0.604539  -0.220131       1.089815   0.454458
# max           2.183036   1.598363   1.070907       2.828711   5.659660
#
#        experience  languages
# count   81.000000  81.000000
# mean    -0.316693   0.185942
# std      0.541653   0.599550
# min     -0.753450  -1.564892
# 25%     -0.702341  -0.263813
# 50%     -0.451910   0.169880
# 75%     -0.140148   0.603573
# max      2.681040   1.687805

# %% [markdown]
# # Export results

# %%
df_train.to_parquet("data/df_train_cleaned.parquet")
df_predict.to_parquet("data/df_predict_cleaned.parquet")
